# %% [markdown]
# ## Trading Strategies

# %% [markdown]
# ## Simple Moving Average

# %%
import numpy as np
import pandas as pd
import datetime as dt
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
import pandas_datareader.data as web
data = web.DataReader('IOC.NS', 'yahoo', '2016-01-01','2022-09-30')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1666 entries, 2016-01-01 to 2022-09-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1666 non-null   float64
#  1   Low        1666 non-null   float64
#  2   Open       1666 non-null   float64
#  3   Close      1666 non-null   float64
#  4   Volume     1666 non-null   float64
#  5   Adj Close  1666 non-null   float64
# dtypes: float64(6)
# memory usage: 91.1 KB

# %% [markdown]
# SMA1 = 42
# SMA2 = 252
#
# data['SMA1'] = data['Close'].rolling(SAM1).mean()
# data['SMA2'] = data['Close'].rolling(SAM2).mean()
#
# data.plot(figsize(10,6))

# %%
SMA1 = 42
SMA2 = 252

data['SMA1'] = data['Close'].rolling(SMA1).mean()
data['SMA2'] = data['Close'].rolling(SMA2).mean()

data[['Close','SMA1','SMA2']].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['Position'] = np.where(data['SMA1']> data['SMA2'], 1, -1)
data
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2016-01-01  72.449997  71.333336  71.349998  72.208336   3754404.0  44.905449
# 2016-01-04  72.208336  70.333336  72.166664  71.074997   6017748.0  44.200638
# 2016-01-05  74.333336  71.083336  71.308334  73.775002   7926444.0  45.879738
# 2016-01-06  76.000000  73.500000  74.150002  75.141663  14527062.0  46.729641
# 2016-01-07  75.391663  72.550003  74.066666  73.591667  13516104.0  45.765717
# ...               ...        ...        ...        ...         ...        ...
# 2022-09-22  68.250000  67.500000  68.199997  67.800003  15775504.0  67.800003
# 2022-09-23  67.949997  67.199997  67.800003  67.449997  13578280.0  67.449997
# 2022-09-26  67.400002  65.900002  67.199997  66.050003  19194238.0  66.050003
# 2022-09-27  67.099998  66.099998  66.400002  66.750000  14140070.0  66.750000
# 2022-09-28  66.400002  66.050003  66.400002  65.750000  15962918.0  65.750000
#
#                  SMA1       SMA2  Position
# Date
# 2016-01-01        NaN        NaN        -1
# 2016-01-04        NaN        NaN        -1
# 2016-01-05        NaN        NaN        -1
# 2016-01-06        NaN        NaN        -1
# 2016-01-07        NaN        NaN        -1
# ...               ...        ...       ...
# 2022-09-22  71.526191  78.785449        -1
# 2022-09-23  71.414286  78.749934        -1
# 2022-09-26  71.270238  78.707804        -1
# 2022-09-27  71.153572  78.664616        -1
# 2022-09-28  71.002381  78.613360        -1
#
# [1666 rows x 9 columns]

# %%
ax = data[['Close','SMA1','SMA2', 'Position']].plot(secondary_y = 'Position', figsize=(10,6))
ax.legend().set_bbox_to_anchor((0.25,0.85))
