# %% [markdown]
# ## Trading Strategies

# %% [markdown]
# ## Simple Moving Average

# %%
import numpy as np
import pandas as pd
import datetime as dt
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
import pandas_datareader.data as web
data = web.DataReader('INFY.NS', 'yahoo', '2016-01-01','2022-09-30')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1666 entries, 2016-01-01 to 2022-09-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1666 non-null   float64
#  1   Low        1666 non-null   float64
#  2   Open       1666 non-null   float64
#  3   Close      1666 non-null   float64
#  4   Volume     1666 non-null   float64
#  5   Adj Close  1666 non-null   float64
# dtypes: float64(6)
# memory usage: 91.1 KB

# %% [markdown]
# SMA1 = 42
# SMA2 = 252
#
# data['SMA1'] = data['Close'].rolling(SAM1).mean()
# data['SMA2'] = data['Close'].rolling(SAM2).mean()
#
# data.plot(figsize(10,6))

# %%
SMA1 = 42
SMA2 = 252

data['SMA1'] = data['Close'].rolling(SMA1).mean()
data['SMA2'] = data['Close'].rolling(SMA2).mean()

data[['Close','SMA1','SMA2']].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['Position'] = np.where(data['SMA1']> data['SMA2'], 1, -1)
data
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2016-01-01   554.474976   546.599976   550.000000   552.625000   1806550.0
# 2016-01-04   551.224976   538.025024   549.974976   539.450012   3975362.0
# 2016-01-05   542.750000   531.125000   542.750000   537.025024   4949786.0
# 2016-01-06   537.325012   529.450012   537.325012   534.674988   5588328.0
# 2016-01-07   533.950012   523.950012   530.025024   525.400024   5294088.0
# ...                 ...          ...          ...          ...         ...
# 2022-09-22  1383.949951  1360.000000  1366.349976  1367.949951   9168498.0
# 2022-09-23  1394.800049  1362.000000  1367.500000  1365.449951  10426200.0
# 2022-09-26  1399.449951  1355.000000  1360.000000  1380.250000   9414587.0
# 2022-09-27  1406.500000  1378.000000  1393.449951  1393.550049   8561254.0
# 2022-09-28  1405.849976  1377.000000  1379.000000  1394.699951   7020498.0
#
#               Adj Close         SMA1         SMA2  Position
# Date
# 2016-01-01   467.716919          NaN          NaN        -1
# 2016-01-04   456.566315          NaN          NaN        -1
# 2016-01-05   454.513885          NaN          NaN        -1
# 2016-01-06   452.524902          NaN          NaN        -1
# 2016-01-07   444.674988          NaN          NaN        -1
# ...                 ...          ...          ...       ...
# 2022-09-22  1367.949951  1512.246431  1654.740477        -1
# 2022-09-23  1365.449951  1508.892857  1653.461112        -1
# 2022-09-26  1380.250000  1505.955953  1652.119049        -1
# 2022-09-27  1393.550049  1504.584525  1650.835914        -1
# 2022-09-28  1394.699951  1502.766666  1649.455556        -1
#
# [1666 rows x 9 columns]

# %%
ax = data[['Close','SMA1','SMA2', 'Position']].plot(secondary_y = 'Position', figsize=(10,6))
ax.legend().set_bbox_to_anchor((0.25,0.85))
