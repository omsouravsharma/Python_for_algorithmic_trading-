# %% [markdown]
# ## Trading Strategies

# %% [markdown]
# ## Simple Moving Average

# %%
import numpy as np
import pandas as pd
import datetime as dt
from pylab import mpl, plt
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
import pandas_datareader.data as web
data = web.DataReader('TATAMOTORS.NS', 'yahoo', '2016-01-01','2022-09-30')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1666 entries, 2016-01-01 to 2022-09-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       1666 non-null   float64
#  1   Low        1666 non-null   float64
#  2   Open       1666 non-null   float64
#  3   Close      1666 non-null   float64
#  4   Volume     1666 non-null   float64
#  5   Adj Close  1666 non-null   float64
# dtypes: float64(6)
# memory usage: 91.1 KB

# %% [markdown]
# SMA1 = 42
# SMA2 = 252
#
# data['SMA1'] = data['Close'].rolling(SAM1).mean()
# data['SMA2'] = data['Close'].rolling(SAM2).mean()
#
# data.plot(figsize(10,6))

# %%
SMA1 = 42
SMA2 = 252

data['SMA1'] = data['Close'].rolling(SMA1).mean()
data['SMA2'] = data['Close'].rolling(SMA2).mean()

data[['Close','SMA1','SMA2']].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data['Position'] = np.where(data['SMA1']> data['SMA2'], 1, -1)
data
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2016-01-01  403.000000  373.000000  392.500000  401.899994   4377363.0
# 2016-01-04  400.100006  375.049988  400.000000  377.049988   7822660.0
# 2016-01-05  382.450012  372.100006  381.049988  374.450012   6901068.0
# 2016-01-06  375.500000  364.600006  374.250000  365.899994   7211230.0
# 2016-01-07  358.000000  338.100006  356.250000  343.549988  11782307.0
# ...                ...         ...         ...         ...         ...
# 2022-09-22  434.600006  422.549988  425.000000  432.200012  13600786.0
# 2022-09-23  431.899994  420.549988  431.899994  423.100006  13441609.0
# 2022-09-26  417.899994  393.149994  416.000000  397.500000  33230938.0
# 2022-09-27  404.000000  390.350006  403.899994  398.799988  21932747.0
# 2022-09-28  406.600006  392.850006  394.899994  399.100006  18092640.0
#
#              Adj Close        SMA1        SMA2  Position
# Date
# 2016-01-01  401.737305         NaN         NaN        -1
# 2016-01-04  376.897339         NaN         NaN        -1
# 2016-01-05  374.298431         NaN         NaN        -1
# 2016-01-06  365.751862         NaN         NaN        -1
# 2016-01-07  343.410919         NaN         NaN        -1
# ...                ...         ...         ...       ...
# 2022-09-22  432.200012  457.894047  449.699207         1
# 2022-09-23  423.100006  457.136905  450.191865         1
# 2022-09-26  397.500000  455.897619  450.571032         1
# 2022-09-27  398.799988  454.889286  450.923016         1
# 2022-09-28  399.100006  453.819048  451.230953         1
#
# [1666 rows x 9 columns]

# %%
ax = data[['Close','SMA1','SMA2', 'Position']].plot(secondary_y = 'Position', figsize=(10,6))
ax.legend().set_bbox_to_anchor((0.25,0.85))
